# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Business Formation Statistics.xlsx')

# %%
df.head(20).sort_values('')
# Out:
#          Date                           category state abbr          state  \
# 0  2005-07-01     Transportation and Warehousing         US     U.S. Total
# 1  2007-02-01  Health Care and Social Assistance         US     U.S. Total
# 2  2014-09-01                        Information         US     U.S. Total
# 3  2012-03-01              Professional Services         US     U.S. Total
# 4  2006-12-01                        Agriculture         US     U.S. Total
# 5  2017-10-01                Total for All NAICS         SD   South Dakota
# 6  2012-02-01              Finance and Insurance         US     U.S. Total
# 7  2013-09-01                Total for All NAICS         WA     Washington
# 8  2005-09-01                       Construction         US     U.S. Total
# 9  2019-03-01                Total for All NAICS         ID          Idaho
# 10 2020-06-01                Total for All NAICS         IA           Iowa
# 11 2021-01-01                Total for All NAICS         CA     California
# 12 2007-01-01                Total for All NAICS         NO      Northeast
# 13 2011-04-01                Total for All NAICS         MI       Michigan
# 14 2021-03-01                Total for All NAICS         NY       New York
# 15 2015-10-01                Total for All NAICS         WV  West Virginia
# 16 2015-02-01                Total for All NAICS         MS    Mississippi
# 17 2020-06-01                Total for All NAICS         AK         Alaska
# 18 2010-03-01                Total for All NAICS         ID          Idaho
# 19 2007-03-01     Transportation and Warehousing         US     U.S. Total
#
#     Business Applications from Corporations  Business Applications      Month
# 0                                      5852                  19769       July
# 1                                      8505                  29226   February
# 2                                      2142                   8624  September
# 3                                     17239                  74361      March
# 4                                      1313                   5751   December
# 5                                        89                   1377    October
# 6                                      3786                  21082   February
# 7                                      1096                   7105  September
# 8                                     19361                  54289  September
# 9                                       277                   4023      March
# 10                                      270                   3957       June
# 11                                    21010                  96237    January
# 12                                    23534                  69842    January
# 13                                     2369                  14885      April
# 14                                    15351                  60193      March
# 15                                      135                   1407    October
# 16                                      350                   3872   February
# 17                                       52                   1489       June
# 18                                      330                   2283      March
# 19                                     8410                  27501      March

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16492 entries, 0 to 16491
# Data columns (total 6 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   month                                    16492 non-null  datetime64[ns]
#  1   category                                 16492 non-null  object
#  2   state abbr                               16492 non-null  object
#  3   state                                    16492 non-null  object
#  4   Business Applications from Corporations  16492 non-null  int64
#  5   Business Applications                    16492 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 773.2+ KB

# %%
df = df.convert_dtypes()

# %%
df.nunique()
# Out:
# month                                        217
# category                                      21
# state abbr                                    56
# state                                         56
# Business Applications from Corporations     7002
# Business Applications                      12471
# dtype: int64

# %%
df[['category','state']] = df[['category','state']].astype('category')
df.dtypes
# Out:
# month                                      datetime64[ns]
# category                                         category
# state abbr                                         string
# state                                            category
# Business Applications from Corporations             Int64
# Business Applications                               Int64
# dtype: object

# %%
df['category'].unique()
# Out:
# ['Transportation and Warehousing', 'Health Care and Social Assistance', 'Information', 'Professional Services', 'Agriculture', ..., 'No NAICS Assigned', 'Retail Trade', 'Mining', 'Accommodation and Food Services', 'Administrative and Support']
# Length: 21
# Categories (21, string): [Accommodation and Food Services, Administrative and Support, Agriculture, Arts and Entertainment, ..., Total for All NAICS, Transportation and Warehousing, Utilities, Wholesale Trade]

# %%
df['state'].unique()
# Out:
# ['U.S. Total', 'South Dakota', 'Washington', 'Idaho', 'Iowa', ..., 'Montana', 'Connecticut', 'West', 'Virginia', 'Florida']
# Length: 56
# Categories (56, string): [Alabama, Alaska, Arizona, Arkansas, ..., West, West Virginia, Wisconsin, Wyoming]

# %%
df = df.rename(columns={'month':'Date'})

# %%
df['Date'] = df['Date'].dt.strftime('%Y-%d-%m')
df['Date']
# Out:
# 0        2005-07-01
# 1        2007-02-01
# 2        2014-09-01
# 3        2012-03-01
# 4        2006-12-01
#             ...
# 16487    2011-02-01
# 16488    2012-08-01
# 16489    2009-12-01
# 16490    2005-11-01
# 16491    2014-10-01
# Name: Date, Length: 16492, dtype: object

# %%
df['Date'] = pd.to_datetime(
    df['Date'],
    errors = 'coerce',
    format= '%Y-%m-%d'
    
    )

# %%
df['Month'] = df['Date'].dt.month_name()

# %%
df_copy = df.copy(deep=True)

# %%
sns.lineplot(data=df_copy, x='Date', y='Business Applications')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Business Applications'>

# %%
sns.boxplot(data=df_copy, x='Month', y='Business Applications')
plt.xticks(rotation=90)
plt.show()

# %%
condition_totals_state = df_copy['state'] == 'U.S. Total'
df_copy = df_copy[condition_totals_state]  
df_copy['category'].unique().tolist()
# Out:
# ['Transportation and Warehousing',
#  'Health Care and Social Assistance',
#  'Information',
#  'Professional Services',
#  'Agriculture',
#  'Finance and Insurance',
#  'Construction',
#  'Real Estate',
#  'Utilities',
#  'Wholesale Trade',
#  'Management of Companies',
#  'Other Services',
#  'Arts and Entertainment',
#  'Manufacturing',
#  'Total for All NAICS',
#  'Educational Services',
#  'No NAICS Assigned',
#  'Retail Trade',
#  'Mining',
#  'Accommodation and Food Services',
#  'Administrative and Support']

# %%
condition_total_category = df_copy['category'] == 'Total for All NAICS'
df_copy = df_copy[condition_total_category]
df_copy
# Out:
#             Date             category state abbr       state  \
# 84    2006-08-01  Total for All NAICS         US  U.S. Total
# 204   2009-05-01  Total for All NAICS         US  U.S. Total
# 243   2012-04-01  Total for All NAICS         US  U.S. Total
# 366   2008-12-01  Total for All NAICS         US  U.S. Total
# 464   2018-04-01  Total for All NAICS         US  U.S. Total
# ...          ...                  ...        ...         ...
# 16331 2008-11-01  Total for All NAICS         US  U.S. Total
# 16368 2022-02-01  Total for All NAICS         US  U.S. Total
# 16394 2014-02-01  Total for All NAICS         US  U.S. Total
# 16405 2006-05-01  Total for All NAICS         US  U.S. Total
# 16442 2012-01-01  Total for All NAICS         US  U.S. Total
#
#        Business Applications from Corporations  Business Applications  \
# 84                                      150106                 462621
# 204                                      99663                 397634
# 243                                      91582                 442912
# 366                                      92618                 365108
# 464                                      93739                 577266
# ...                                        ...                    ...
# 16331                                    94682                 375855
# 16368                                    99047                 865472
# 16394                                    89928                 458678
# 16405                                   166504                 498235
# 16442                                    78311                 363133
#
#           Month
# 84       August
# 204         May
# 243       April
# 366    December
# 464       April
# ...         ...
# 16331  November
# 16368  February
# 16394  February
# 16405       May
# 16442   January
#
# [217 rows x 7 columns]

# %%
sns.boxplot(data=df_copy, x='Month', y='Business Applications')
plt.xticks(rotation=90)
plt.show()

# %%
sns.set(palette='dark')
sns.lineplot(data=df_copy,x='Date', y='Business Applications')
sns.lineplot(data=df_copy,x='Date', y='Business Applications from Corporations')
plt.show()
